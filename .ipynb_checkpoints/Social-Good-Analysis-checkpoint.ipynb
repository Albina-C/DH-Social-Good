# %%
# import packages here
import pandas as pd
import numpy as np
import sqlite3 as sq
from scipy import stats
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"]=10,10

# %%
crime=pd.read_csv('May8Crime.csv')

# %%
crime.head()
# Out:
#    Unnamed: 0 incident_number offense_code_group  \
# 0           0      I182070943          Vandalism
# 1           1      I182070872          Vandalism
# 2           2      I182070857      Property Lost
# 3           3      I182070841              Fraud
# 4           4      I182070834            Larceny
#
#                offense_description occurred_on_date  month day_of_week  hour  \
# 0                        VANDALISM   2018/8/21 0:00      8     Tuesday     0
# 1                        VANDALISM  2018/8/31 17:00      8      Friday    17
# 2                  PROPERTY - LOST  2018/8/22 14:00      8   Wednesday    14
# 3  FRAUD - FALSE PRETENSE / SCHEME  2018/8/20 12:00      8      Monday    12
# 4      LARCENY THEFT FROM BUILDING  2018/8/23 10:41      8    Thursday    10
#
#            street        lat       long                     location  \
# 0        HECLA ST  42.306821 -71.060300  (42.30682138, -71.06030035)
# 1            A ST  42.347543 -71.050662  (42.34754258, -71.05066210)
# 2  HUNTINGTON AVE  42.344812 -71.082343  (42.34481182, -71.08234324)
# 3      SHEPARD ST  42.346002 -71.151120  (42.34600153, -71.15112006)
# 4    RADCLIFFE RD  42.350854 -71.134089  (42.35085449, -71.13408859)
#
#    Missing_Data
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
crime= crime.drop(columns=['Unnamed: 0'])

# %%
crime.head()
# Out:
#   incident_number offense_code_group              offense_description  \
# 0      I182070943          Vandalism                        VANDALISM
# 1      I182070872          Vandalism                        VANDALISM
# 2      I182070857      Property Lost                  PROPERTY - LOST
# 3      I182070841              Fraud  FRAUD - FALSE PRETENSE / SCHEME
# 4      I182070834            Larceny      LARCENY THEFT FROM BUILDING
#
#   occurred_on_date  month day_of_week  hour          street        lat  \
# 0   2018/8/21 0:00      8     Tuesday     0        HECLA ST  42.306821
# 1  2018/8/31 17:00      8      Friday    17            A ST  42.347543
# 2  2018/8/22 14:00      8   Wednesday    14  HUNTINGTON AVE  42.344812
# 3  2018/8/20 12:00      8      Monday    12      SHEPARD ST  42.346002
# 4  2018/8/23 10:41      8    Thursday    10    RADCLIFFE RD  42.350854
#
#         long                     location  Missing_Data
# 0 -71.060300  (42.30682138, -71.06030035)             0
# 1 -71.050662  (42.34754258, -71.05066210)             0
# 2 -71.082343  (42.34481182, -71.08234324)             0
# 3 -71.151120  (42.34600153, -71.15112006)             0
# 4 -71.134089  (42.35085449, -71.13408859)             0

# %%
crime.describe()
# Out:
#               month          hour           lat          long  Missing_Data
# count  50299.000000  50299.000000  47025.000000  47025.000000  50299.000000
# mean       5.546114     13.121235     42.150497    -70.805816      0.068789
# std        1.680265      6.260998      2.719398      4.399048      0.253097
# min        3.000000      0.000000     -1.000000    -71.178674      0.000000
# 25%        4.000000      9.000000     42.296816    -71.097074      0.000000
# 50%        6.000000     14.000000     42.325029    -71.077683      0.000000
# 75%        7.000000     18.000000     42.348175    -71.062563      0.000000
# max        8.000000     23.000000     42.395042     -1.000000      1.000000

# %% [markdown]
# Creating dataframe for crimes WITHOUT location data

# %%
df1= crime[crime['Missing_Data']==1]
df2= crime[crime['Missing_Data']==0]

# %%
def piechart(merged_frequency):
    print(merged_frequency)
    sorted_x = merged_frequency.sort_values('count_x')
    print(sorted_x)
    index = sorted_x['index']
    print(index)
    x = sorted_x['count_x']
    print(x)
    fig1,ax1 = plt.subplots()
    ax1.pie(x,labels=index,startangle=90,textprops={'fontsize':10}, labeldistance=1.2)
    ax1.axis('equal')

# %%
def compare(missing,normal,column_name):
    column_name = str(column_name)
    n=0

    for i in [missing,normal]:
        n+=1
        ser = i[column_name].value_counts()
        list_ser = list(ser)
        compare_index = list(ser.index)
        d={'index':compare_index, 'count':list_ser}
        df = pd.DataFrame(data=d)

        frequency = df.sort_values('index')
        frequency = frequency.reset_index()
        frequency = frequency.drop(columns=['level_0'])

        if n==1:
            frequency_missing = frequency
        else:
            frequency_normal = frequency

    merged_frequency= frequency_missing.merge(frequency_normal,how='inner',on='index')
    # Contingency Table
    #print(merged_frequency)
    mf=merged_frequency.to_numpy()
    mf = np.transpose(mf)
    mf = mf[1:3]
    chi2, p, dof, ex = chi2_contingency(mf)
    #print("chi2",chi2)
    print("p-value",p)
    #print("expected table",ex)
    #Normalized table
    index = merged_frequency['index']
    x = merged_frequency['count_x']
    y = merged_frequency['count_y']
    
    sum_x = sum(x)
    for j in range(len(x)):
        v = float(x[j]/sum_x)
        x.loc[j]=v
    
    sum_y = sum(y)
    for j in range(len(y)):
        v = float(y[j]/sum_y)
        y.loc[j]=v
        
    if column_name == 'offense_code_group':
        piechart(merged_frequency)
    else:        
    #Comparative bar chart
        X_axis = np.arange(len(index))
        plt.bar(X_axis - 0.2, x, 0.4, tick_label=index, label = 'missing')
        plt.bar(X_axis + 0.2, y, 0.4, label = 'normal')
    
    return(merged_frequency)

# %%
output_hour = compare(df1,df2,'hour')
output_hour['residuals']=output_hour['count_x']-output_hour['count_y']
output_hour
plt.ylabel('output hour distribution')
plt.xlabel('hours')
plt.show()
# Out:
# p-value 3.764353934910259e-12

# %%
output_hour
# Out:
#     index   count_x   count_y  residuals
# 0       0  0.049133  0.046436   0.002697
# 1       1  0.038439  0.026730   0.011709
# 2       2  0.035260  0.022737   0.012523
# 3       3  0.011850  0.013450  -0.001601
# 4       4  0.013295  0.011123   0.002172
# 5       5  0.013295  0.010483   0.002812
# 6       6  0.016763  0.016290   0.000473
# 7       7  0.023410  0.028267  -0.004857
# 8       8  0.041040  0.041611  -0.000570
# 9       9  0.031503  0.046735  -0.015232
# 10     10  0.040751  0.054463  -0.013712
# 11     11  0.045376  0.053545  -0.008169
# 12     12  0.053757  0.059459  -0.005702
# 13     13  0.051445  0.054122  -0.002676
# 14     14  0.057225  0.056043   0.001182
# 15     15  0.049133  0.051389  -0.002256
# 16     16  0.057514  0.060249  -0.002734
# 17     17  0.073988  0.061872   0.012117
# 18     18  0.076879  0.061807   0.015071
# 19     19  0.056069  0.054036   0.002033
# 20     20  0.043931  0.050898  -0.006967
# 21     21  0.043642  0.044834  -0.001193
# 22     22  0.043353  0.040159   0.003194
# 23     23  0.032948  0.033263  -0.000315

# %%
plt.scatter(output_hour['index'],output_hour['residuals'])
plt.ylabel('output hour residuals')
plt.xlabel('output hour')
plt.show()

# %%
output_month = compare(df1,df2,'month')
# output_month
plt.ylabel('output month distribution')
plt.xlabel('output month frequencies')
plt.show()
# Out:
# p-value 0.015256857019783004

# %%
output_month
# Out:
#    index   count_x   count_y
# 0      3  0.155202  0.154380
# 1      4  0.135838  0.158970
# 2      5  0.187283  0.176306
# 3      6  0.178324  0.175431
# 4      7  0.174855  0.169367
# 5      8  0.168497  0.165546

# %%
output_day = compare(df1,df2,'day_of_week')
output_day
plt.xticks(rotation=(90))
plt.ylabel('output day of the week distribution')
plt.xlabel('output day of the week frequencies')
plt.show()
# Out:
# p-value 0.4098689111922154

# %%
output_day
# Out:
#        index   count_x   count_y
# 0     Friday  0.152601  0.156323
# 1     Monday  0.133815  0.140588
# 2   Saturday  0.135549  0.138752
# 3     Sunday  0.123410  0.123508
# 4   Thursday  0.157225  0.151391
# 5    Tuesday  0.155780  0.143449
# 6  Wednesday  0.141618  0.145989

# %%
# figure(figsize=(10,10))
output_offense = compare(df1,df2,'offense_code_group')
# output_offense
# plt.xticks(rotation=(180),fontsize=5,va='top',ha='left')
# fig=plt.figure()


plt.figure(figsize=(500,500),dpi=1000)
# Out:
# p-value 0.0
#                                index   count_x   count_y
# 0                 Aggravated Assault  0.026590  0.025240
# 1                           Aircraft  0.000289  0.000085
# 2                              Arson  0.000289  0.000256
# 3   Assembly or Gathering Violations  0.002023  0.002009
# 4                         Auto Theft  0.013295  0.014939
# 5                Auto Theft Recovery  0.004335  0.003334
# 6                         Ballistics  0.001445  0.002949
# 7                Commercial Burglary  0.000289  0.003697
# 8                   Confidence Games  0.002312  0.008549
# 9                     Counterfeiting  0.000578  0.003505
# 10                Disorderly Conduct  0.010405  0.006561
# 11                    Drug Violation  0.090462  0.045095
# 12                      Embezzlement  0.000289  0.000620
# 13                      Evading Fare  0.001734  0.001282
# 14                        Explosives  0.000289  0.000128
# 15              Fire Related Reports  0.004624  0.006048
# 16                 Firearm Discovery  0.000578  0.001945
# 17                Firearm Violations  0.009827  0.005087
# 18                             Fraud  0.008671  0.020902
# 19                        Harassment  0.003179  0.013080
# 20          Harbor Related Incidents  0.006647  0.000299
# 21                          Homicide  0.000289  0.000492
# 22                Investigate Person  0.032659  0.060013
# 23              Investigate Property  0.026879  0.040180
# 24          Landlord/Tenant Disputes  0.000578  0.003591
# 25                           Larceny  0.044220  0.083095
# 26        Larceny From Motor Vehicle  0.019653  0.032357
# 27   License Plate Related Incidents  0.001734  0.001817
# 28                 License Violation  0.001734  0.005450
# 29                  Liquor Violation  0.004046  0.003526
# 30                Medical Assistance  0.056936  0.087690
# 31            Missing Person Located  0.004046  0.014832
# 32           Missing Person Reported  0.002601  0.011477
# 33   Motor Vehicle Accident Response  0.308382  0.103056
# 34   Offenses Against Child / Family  0.000867  0.001688
# 35     Operating Under the Influence  0.004913  0.001261
# 36                             Other  0.043931  0.056679
# 37                    Other Burglary  0.000578  0.001325
# 38          Police Service Incidents  0.017919  0.010494
# 39        Prisoner Related Incidents  0.001156  0.000855
# 40                    Property Found  0.013873  0.014298
# 41                     Property Lost  0.019364  0.036739
# 42           Property Related Damage  0.002312  0.003013
# 43         Recovered Stolen Property  0.006358  0.004531
# 44              Residential Burglary  0.001445  0.014041
# 45      Restraining Order Violations  0.001734  0.004638
# 46                           Robbery  0.013006  0.011007
# 47                   Search Warrants  0.001156  0.002522
# 48                           Service  0.001445  0.000919
# 49                    Simple Assault  0.043931  0.055439
# 50                             Towed  0.032659  0.041889
# 51                         Vandalism  0.023988  0.043984
# 52                   Verbal Disputes  0.008671  0.048963
# 53                        Violations  0.047399  0.015944
# 54                   Warrant Arrests  0.021387  0.016585
#                                index   count_x   count_y
# 1                           Aircraft  0.000289  0.000085
# 2                              Arson  0.000289  0.000256
# 21                          Homicide  0.000289  0.000492
# 14                        Explosives  0.000289  0.000128
# 12                      Embezzlement  0.000289  0.000620
# 7                Commercial Burglary  0.000289  0.003697
# 24          Landlord/Tenant Disputes  0.000578  0.003591
# 37                    Other Burglary  0.000578  0.001325
# 16                 Firearm Discovery  0.000578  0.001945
# 9                     Counterfeiting  0.000578  0.003505
# 34   Offenses Against Child / Family  0.000867  0.001688
# 47                   Search Warrants  0.001156  0.002522
# 39        Prisoner Related Incidents  0.001156  0.000855
# 48                           Service  0.001445  0.000919
# 6                         Ballistics  0.001445  0.002949
# 44              Residential Burglary  0.001445  0.014041
# 45      Restraining Order Violations  0.001734  0.004638
# 28                 License Violation  0.001734  0.005450
# 27   License Plate Related Incidents  0.001734  0.001817
# 13                      Evading Fare  0.001734  0.001282
# 3   Assembly or Gathering Violations  0.002023  0.002009
# 42           Property Related Damage  0.002312  0.003013
# 8                   Confidence Games  0.002312  0.008549
# 32           Missing Person Reported  0.002601  0.011477
# 19                        Harassment  0.003179  0.013080
# 29                  Liquor Violation  0.004046  0.003526
# 31            Missing Person Located  0.004046  0.014832
# 5                Auto Theft Recovery  0.004335  0.003334
# 15              Fire Related Reports  0.004624  0.006048
# 35     Operating Under the Influence  0.004913  0.001261
# 43         Recovered Stolen Property  0.006358  0.004531
# 20          Harbor Related Incidents  0.006647  0.000299
# 18                             Fraud  0.008671  0.020902
# 52                   Verbal Disputes  0.008671  0.048963
# 17                Firearm Violations  0.009827  0.005087
# 10                Disorderly Conduct  0.010405  0.006561
# 46                           Robbery  0.013006  0.011007
# 4                         Auto Theft  0.013295  0.014939
# 40                    Property Found  0.013873  0.014298
# 38          Police Service Incidents  0.017919  0.010494
# 41                     Property Lost  0.019364  0.036739
# 26        Larceny From Motor Vehicle  0.019653  0.032357
# 54                   Warrant Arrests  0.021387  0.016585
# 51                         Vandalism  0.023988  0.043984
# 0                 Aggravated Assault  0.026590  0.025240
# 23              Investigate Property  0.026879  0.040180
# 22                Investigate Person  0.032659  0.060013
# 50                             Towed  0.032659  0.041889
# 49                    Simple Assault  0.043931  0.055439
# 36                             Other  0.043931  0.056679
# 25                           Larceny  0.044220  0.083095
# 53                        Violations  0.047399  0.015944
# 30                Medical Assistance  0.056936  0.087690
# 11                    Drug Violation  0.090462  0.045095
# 33   Motor Vehicle Accident Response  0.308382  0.103056
# 1                             Aircraft
# 2                                Arson
# 21                            Homicide
# 14                          Explosives
# 12                        Embezzlement
# 7                  Commercial Burglary
# 24            Landlord/Tenant Disputes
# 37                      Other Burglary
# 16                   Firearm Discovery
# 9                       Counterfeiting
# 34     Offenses Against Child / Family
# 47                     Search Warrants
# 39          Prisoner Related Incidents
# 48                             Service
# 6                           Ballistics
# 44                Residential Burglary
# 45        Restraining Order Violations
# 28                   License Violation
# 27     License Plate Related Incidents
# 13                        Evading Fare
# 3     Assembly or Gathering Violations
# 42             Property Related Damage
# 8                     Confidence Games
# 32             Missing Person Reported
# 19                          Harassment
# 29                    Liquor Violation
# 31              Missing Person Located
# 5                  Auto Theft Recovery
# 15                Fire Related Reports
# 35       Operating Under the Influence
# 43           Recovered Stolen Property
# 20            Harbor Related Incidents
# 18                               Fraud
# 52                     Verbal Disputes
# 17                  Firearm Violations
# 10                  Disorderly Conduct
# 46                             Robbery
# 4                           Auto Theft
# 40                      Property Found
# 38            Police Service Incidents
# 41                       Property Lost
# 26          Larceny From Motor Vehicle
# 54                     Warrant Arrests
# 51                           Vandalism
# 0                   Aggravated Assault
# 23                Investigate Property
# 22                  Investigate Person
# 50                               Towed
# 49                      Simple Assault
# 36                               Other
# 25                             Larceny
# 53                          Violations
# 30                  Medical Assistance
# 11                      Drug Violation
# 33     Motor Vehicle Accident Response
# Name: index, dtype: object
# 1     0.000289
# 2     0.000289
# 21    0.000289
# 14    0.000289
# 12    0.000289
# 7     0.000289
# 24    0.000578
# 37    0.000578
# 16    0.000578
# 9     0.000578
# 34    0.000867
# 47    0.001156
# 39    0.001156
# 48    0.001445
# 6     0.001445
# 44    0.001445
# 45    0.001734
# 28    0.001734
# 27    0.001734
# 13    0.001734
# 3     0.002023
# 42    0.002312
# 8     0.002312
# 32    0.002601
# 19    0.003179
# 29    0.004046
# 31    0.004046
# 5     0.004335
# 15    0.004624
# 35    0.004913
# 43    0.006358
# 20    0.006647
# 18    0.008671
# 52    0.008671
# 17    0.009827
# 10    0.010405
# 46    0.013006
# 4     0.013295
# 40    0.013873
# 38    0.017919
# 41    0.019364
# 26    0.019653
# 54    0.021387
# 51    0.023988
# 0     0.026590
# 23    0.026879
# 22    0.032659
# 50    0.032659
# 49    0.043931
# 36    0.043931
# 25    0.044220
# 53    0.047399
# 30    0.056936
# 11    0.090462
# 33    0.308382
# Name: count_x, dtype: float64

# %%
output_offense
# Out:
#                                index   count_x   count_y
# 0                 Aggravated Assault  0.026590  0.025240
# 1                           Aircraft  0.000289  0.000085
# 2                              Arson  0.000289  0.000256
# 3   Assembly or Gathering Violations  0.002023  0.002009
# 4                         Auto Theft  0.013295  0.014939
# 5                Auto Theft Recovery  0.004335  0.003334
# 6                         Ballistics  0.001445  0.002949
# 7                Commercial Burglary  0.000289  0.003697
# 8                   Confidence Games  0.002312  0.008549
# 9                     Counterfeiting  0.000578  0.003505
# 10                Disorderly Conduct  0.010405  0.006561
# 11                    Drug Violation  0.090462  0.045095
# 12                      Embezzlement  0.000289  0.000620
# 13                      Evading Fare  0.001734  0.001282
# 14                        Explosives  0.000289  0.000128
# 15              Fire Related Reports  0.004624  0.006048
# 16                 Firearm Discovery  0.000578  0.001945
# 17                Firearm Violations  0.009827  0.005087
# 18                             Fraud  0.008671  0.020902
# 19                        Harassment  0.003179  0.013080
# 20          Harbor Related Incidents  0.006647  0.000299
# 21                          Homicide  0.000289  0.000492
# 22                Investigate Person  0.032659  0.060013
# 23              Investigate Property  0.026879  0.040180
# 24          Landlord/Tenant Disputes  0.000578  0.003591
# 25                           Larceny  0.044220  0.083095
# 26        Larceny From Motor Vehicle  0.019653  0.032357
# 27   License Plate Related Incidents  0.001734  0.001817
# 28                 License Violation  0.001734  0.005450
# 29                  Liquor Violation  0.004046  0.003526
# 30                Medical Assistance  0.056936  0.087690
# 31            Missing Person Located  0.004046  0.014832
# 32           Missing Person Reported  0.002601  0.011477
# 33   Motor Vehicle Accident Response  0.308382  0.103056
# 34   Offenses Against Child / Family  0.000867  0.001688
# 35     Operating Under the Influence  0.004913  0.001261
# 36                             Other  0.043931  0.056679
# 37                    Other Burglary  0.000578  0.001325
# 38          Police Service Incidents  0.017919  0.010494
# 39        Prisoner Related Incidents  0.001156  0.000855
# 40                    Property Found  0.013873  0.014298
# 41                     Property Lost  0.019364  0.036739
# 42           Property Related Damage  0.002312  0.003013
# 43         Recovered Stolen Property  0.006358  0.004531
# 44              Residential Burglary  0.001445  0.014041
# 45      Restraining Order Violations  0.001734  0.004638
# 46                           Robbery  0.013006  0.011007
# 47                   Search Warrants  0.001156  0.002522
# 48                           Service  0.001445  0.000919
# 49                    Simple Assault  0.043931  0.055439
# 50                             Towed  0.032659  0.041889
# 51                         Vandalism  0.023988  0.043984
# 52                   Verbal Disputes  0.008671  0.048963
# 53                        Violations  0.047399  0.015944
# 54                   Warrant Arrests  0.021387  0.016585

# %%
output_street = compare(df1,df2,'street')
output_street
plt.ylabel('street distribution')
plt.xlabel('street frequencies')
plt.show()
# Out:
# p-value 0.0

# %%
output_street
# Out:
#                        index   count_x   count_y
# 0                       A ST  0.000774  0.001020
# 1              ABBOTSFORD ST  0.000387  0.000653
# 2                   ADAMS ST  0.006192  0.013132
# 3                  ALBANY ST  0.018963  0.007667
# 4                  ALBERT ST  0.000387  0.000245
# ..                       ...       ...       ...
# 372           WESTMINSTER ST  0.001161  0.000734
# 373              WESTVIEW ST  0.000387  0.001387
# 374  WILLIAM F MCCLELLAN HWY  0.001548  0.001794
# 375                WINTER PL  0.002709  0.000571
# 376              YARMOUTH PL  0.000774  0.000122
#
# [377 rows x 3 columns]

# %% [markdown]
# making dataframe into a numpy array in order to apply to contingency test

# %% [markdown]
# Assumptions: Test of Independence
# 1. Simple Random Sample of n subjects
# 2. Two variables/factors 𝑅, 𝐶 of interest with each having 𝑟, 𝑐 mutually exclusive and exhaustive categories/outcomes/levels, respectively.
# 3. Each subject can be classified according to one level of each factor of interest.
# 4. Expected number of outcomes, assuming independence, for each pairing of levels, across factors, is at least 1. That is, 𝐸  G,[ ≥ 1 for all pairs (𝑖, 𝑗). Further, no more than 20% should be less than 5.
#
# The null hypothesis is that whether the crime location is recorded is independent from the hour of the day.
#
# Since the p-value (7.02e-12) in the chi2 test is significantly lower than 0.05, we reject the null hypothesis.
#
# Whether the crime location is recorded is not independent of the hour of the day.
